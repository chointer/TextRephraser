# %%
from rephrase import Rephrase
from itertools import product

# %%
rephrase = Rephrase()

# %%
### Input
input_prompt = "I found a book in his dark room."
style_types = ["narrative", "emotional", "objective"]
length_types = ["compress", "maintain", "expand"]

outputs = {}

for (style, length) in product(style_types, length_types):
    outputs[(style, length)] = rephrase(input_prompt, style, length)
    
for (style, length) in product(style_types, length_types):
    print(style, length, "\t", outputs[(style, length)])
# Out:
# ##### ##### ##### ##### ##### ##### #####
# --- [STYLE GENERATOR] ---
#
# [SYSTEM]
#  You are a creative writer who rephrases text in a narrative style.
# Your task is to take the user's input and transform it into a more imaginative, colorful, descriptive and engaging version.
# Concentrate writing active motions and I recommend using metaphors.
# Example:
# User: I closed my eyes and left my heavy body to the natural wind.
# Assistant: I closed my eyes in the refreshing breeze and let my body, worn out like a leaf drooping heavily after being drenched in rain, be in the peaceful nature.You may add novel expressions that were not in the original text, but do not take them out of the original context. Never add expressions that create visual differences, such as new objects or emotions. The content of the original text may be reduced, but it should not be contradictory. Therefore, I hope you will change the 'expression' in the original content to satisfy the above conditions.
#
# ...

# %%
outputs[("narrative", "compress")] = "333"
outputs
# Out:
# {('narrative', 'compress'): '333',
#  ('narrative',
#   'maintain'): "In a forsaken sanctuary of perpetual twilight, I chanced upon a tome shrouded in abandonment's heavy mist.",
#  ('narrative',
#   'expand'): 'In the depths of his dark room, I found a mysterious and ancient tome, bound in worn leather with symbols that seemed to whisper forgotten knowledge.',
#  ('emotional',
#   'compress'): 'A dusty, leather-bound book rested on a cluttered, dimly lit shelf.',
#  ('emotional',
#   'maintain'): 'In the depths of darkness, a tattered book lay shrouded in shadows.',
#  ('emotional',
#   'expand'): 'In his darkened sanctum, whispers echoed through the shadows, where forgotten memories lingered like specters, until she chanced upon an old tome with a worn leather cover, radiating an unearthly presence that stirred ancient longings within its weathered pages.',
#  ('objective', 'compress'): 'A book is in a dark room.',
# ...
